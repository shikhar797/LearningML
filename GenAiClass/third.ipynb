# %%
import nltk

# %%
from nltk import word_tokenize ,pos_tag,ne_chunk

# %%
nltk.download('punkt')

# %%
text="""he loives in San Francisco and previously 
he graduated from Standford University in 2018 .His salary is $120000 per year
 """

# %%
#tokenize sentences and words
sentences=nltk.sent_tokenize(text)
tokenize_sentence=[word_tokenize(sentence) for sentence in sentences]

# %%
# apply named entity recognitaion
ner_sentences=[ne_chunk(pos_tags) for pos_tags in pos_tagged_sentences]
