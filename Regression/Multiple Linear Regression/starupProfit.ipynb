# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('starup.csv')
X=df.iloc[:,0:4]
y=df.iloc[:,4:5]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

ct=ColumnTransformer(transformers=[("encoder",OneHotEncoder(),['State'])],remainder="passthrough")
X=ct.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
print(X_train)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
np.set_printoptions(precision=2)
result=np.concatenate((y_pred.reshape(len(y_pred), 1), y_test.to_numpy().reshape(len(y_test),1)), 1)

# %%
print(result)
# Out:
# [[126187.39 134307.35]
#  [ 85788.82  81005.76]
#  [ 99777.03  99937.59]
#  [ 45706.12  64926.08]
#  [127062.21 125370.37]
#  [ 51891.84  35673.41]
#  [109114.63 105733.54]
#  [100600.61 107404.34]
#  [ 97954.    97427.84]
#  [111730.58 122776.86]
#  [128818.49 141585.52]
#  [174195.36 166187.94]
#  [ 93736.29  89949.14]
#  [148381.04 152211.77]
#  [172313.87 182901.99]]

# %%
a=result[:,0]
b=result[:,1]
plt.plot(a)
plt.plot(b)
plt.show()

# %%
from sklearn.metrics import r2_score
accuracy=r2_score(y_test,y_pred)
print("accuracy of the model is :",accuracy*100)
# Out:
# accuracy of the model is : 93.97108063356046
